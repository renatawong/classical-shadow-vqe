# %%
'''
EXPERIMENTS ON BEH2
'''

from qiskit_nature.second_q.mappers import BravyiKitaevMapper
from qiskit_nature.second_q.algorithms import GroundStateEigensolver, NumPyMinimumEigensolverFactory
import numpy as np
import matplotlib.pyplot as plt
import time
from functools import partial
from collections import Counter
from qiskit.circuit.library import EfficientSU2
from qiskit_aer import QasmSimulator
from qiskit import QuantumCircuit, execute
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import BravyiKitaevMapper
from qiskit.algorithms.minimum_eigensolvers import NumPyMinimumEigensolver
from predicting_quantum_properties.data_acquisition_shadow import derandomized_classical_shadow
from predicting_quantum_properties.prediction_shadow import estimate_exp
from modified_derandomization import modified_derandomized_classical_shadow


# SPECIFY THE NUMBER OF EXPERIMENTS YOU WANT TO RUN
num_experiments = 1

# SPECIFY THE EXPECTED GROUND STATE ENERGY FOR THE MOLECULE OF INTEREST
EXPECTED_EIGENVALUE = -19.04

# SPECIFY THE GEOMETRY OF THE MOLECULE IN QUESTION
driver = PySCFDriver(
    atom="Be 0 0 0; H 0 0 1.3264; H 0 0 -1.3264",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)


problem = driver.run()
num_particles = problem.num_particles
hamiltonian = problem.hamiltonian

# The electronic Hamiltonian of the system
second_q_op = hamiltonian.second_q_op()

# Solving the electronic structure problem = determine the ground state energy of the molecule

# The Bravyi-Kitaev repserentation of the Fermionic Hamiltonian
mapper = BravyiKitaevMapper()
bkenc_hamiltonian = mapper.map(second_q_op)


hamiltonian_terms = []
weights = []

for observable in bkenc_hamiltonian:
    
    observable_str = str(observable)
    observable_str_clean = observable_str.strip()  # removes white spaces
    pauli_str_list = observable_str_clean.split('*')
    tuple_list = []
    
    for op_index, pauli_op in enumerate(pauli_str_list[1]):
        if pauli_op == 'I' or pauli_op == 'X' or pauli_op == 'Y' or pauli_op == 'Z':
            tuple_list.append((pauli_op, op_index-1))
    if len(tuple_list) > 0:
        hamiltonian_terms.append(tuple_list)
        weights.append(float(pauli_str_list[0].strip()))

system_size = len(hamiltonian_terms[0])



hamiltonian_terms_XYZE = []

for term in hamiltonian_terms:
    term_XYZE = []
    for pauli in term:
        if pauli[0] != 'I':
            term_XYZE.append(pauli)
    hamiltonian_terms_XYZE.append(term_XYZE)   
    

abs_weights = [abs(weight) for weight in weights]

hamiltonian_terms_XYZ = []
for idx, term in enumerate(hamiltonian_terms_XYZE):
    if term:
        hamiltonian_terms_XYZ.append(term)
    else:
        abs_weights.pop(idx)
        


reps = 1

ansatz = EfficientSU2(system_size, su2_gates=['rx', 'ry'], entanglement='circular', reps=reps, skip_final_rotation_layer=False)

'''
Define the cost function
'''

backend = QasmSimulator(method='statevector', shots=1)


# Create circuit with just the randomised basis change operators
def rand_meas_circuit(pauli_op):
    rand_meas = QuantumCircuit(ansatz.num_qubits)
    for idx, op in enumerate(pauli_op):
        if op == 'X':
            rand_meas.h(idx)
        elif op == 'Y':
            rand_meas.h(idx)
            rand_meas.p(-np.pi/2, idx)
        elif op == 'Z':
            rand_meas.id(idx)
    return rand_meas


def objective_function(operators, params):
    
    # Assign parameters to the ansatz and simulate it
    # Generate circuits to measure random Paulis, one circuit for each Pauli
    
    # Putting repeated operators in derandomized_hamiltonian together and executing one single circuit 
    # as many times as the operator repetitions. 
    
    
    # convert the inner lists to tuples and count duplicates
    pauli_op_dict = Counter(tuple(x) for x in operators)
    
    
    shadow = []
    for pauli_op in pauli_op_dict:
        qc = ansatz.bind_parameters(params)
        qc.compose(rand_meas_circuit(pauli_op))
        qc.measure_all()
        result = execute(qc, backend, shots=pauli_op_dict[pauli_op]).result()
        counts = result.get_counts()
        
        
        # store the shadow in the form [[(Z,1),(Z,-1)...], [(Y,-1),(X,-1),...]] where inner list = snapshot
        # Because measurement output in Qiskit gives us states and not eigenvalues, we need to convert 0->1 and 1->-1
        
        for count in counts:
            for _ in range(counts[count]): # number of repeated measurement values
                output_str = list(count)
                output = [int(i) for i in output_str]
                eigenvals = [x+1 if x == 0 else x-2 for x in output]
                snapshot = [(op, eigenval) for op, eigenval in zip(pauli_op, eigenvals)]
                shadow.append(snapshot)
    
    
    # Now, we want to get the expectation values for the Hamiltonian from the shadow using the function
    # estimate_exp(full_measurement, one_observable)
    # where full_measurement = shadow and one_observable is any term in the Hamiltonian with I observable excluded.
    # cost = the total expectation value of the Hamiltonian
    # NOTE: We need to check for match_count value since it may happen that it is equal to 0. 
    # Such experiments need to be excluded. 
    # The problem is due to the derandomization algorithm not always producing Paulis that 'hit' the Hamiltonian terms.
    
    cost = 0.0
    for term, weight in zip(hamiltonian_terms_XYZE, weights):
        sum_product, match_count = estimate_exp(shadow, term)
        if match_count != 0:
            exp_val = sum_product / match_count
            cost = cost + (weight * exp_val)
            
        
    cost_history.append(cost)
    
    return cost



start_time = time.time()
rmse_errors = []


measurement_range = [1, 250, 500, 750, 1000, 1250, 1500, 1750]
print('NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR\n')

for num_operators in measurement_range:   
    
    derandomized_hamiltonian = modified_derandomized_classical_shadow(hamiltonian_terms_XYZ, 
                                                                    num_operators, system_size, weight=abs_weights)

    cost_function = partial(objective_function, derandomized_hamiltonian)

    tuples = (tuple(pauli) for pauli in derandomized_hamiltonian)
    counts = Counter(tuples)
    

    optimizer = SPSA(maxiter=2000)   
    expectation_values = []
    num_experiments = 10


    for iteration in range(num_experiments):
        cost_history = []
        params = np.random.rand(ansatz.num_parameters)
        result = optimizer.minimize(fun=cost_function, x0=params)
        expectation_values.append(min(cost_history)) 
        print("EXPERIMENT {}: GROUND STATE ENERGY FOUND = {}".format(iteration, min(cost_history)))



    rmse_derandomised_cs = np.sqrt(np.sum([(EXPECTED_EIGENVALUE - expectation_values[i])**2 
                                           for i in range(num_experiments)])/num_experiments)

    rmse_errors.append(rmse_derandomised_cs)
    
    print('{} | {} | {}'.format(num_operators, counts, rmse_derandomised_cs))


elapsed_time = time.time() - start_time
print("Execution time = ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

          
points = measurement_range
num_points = len(measurement_range)

plt.plot([i for i in points], [rmse_errors[i] for i in range(num_points)], 'r', label='SPSA(maxiter=2000)')
plt.xlabel('Number of measurements')
plt.ylabel('Average RMSE error')
plt.legend(loc=1)
# Out:
# /home2/Renata/.conda/envs/py2023/lib/python3.7/site-packages/qiskit_nature/deprecation.py:297: PauliSumOpDeprecationWarning: PauliSumOp is deprecated as of version 0.6.0 and support for them will be removed no sooner than 3 months after the release. Instead, use SparsePauliOp. You can switch to SparsePauliOp immediately, by setting `qiskit_nature.settings.use_pauli_sum_op` to `False`.
#   return func(*args, **kwargs)
# NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR
#
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -12.281851911569335
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -12.281851911569335
# 1 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1}) | 6.758148088430664
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -12.259517636940764
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -12.226898990274506
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -12.186013560034297
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -12.258404945978363
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -12.233913805968886
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -12.171622746254902
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -12.225747120972557
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -12.258324964667613
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -12.258889422145115
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -12.249914431419006
# 250 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 250}) | 6.80714143163428
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -16.849877658497213
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -16.84907910155048
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -16.848958383955573
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -16.857486697828136
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -16.847090995025688
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -16.840852066322412
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -16.847289341225157
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -16.83794445597876
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -16.856690448432378
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -16.849111429366385
# 500 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 499, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 1}) | 2.191569333803129
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -16.84167372128792
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -16.8476027897958
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -16.84079494931912
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -16.845536768334977
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -16.848382358640173
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -16.8367353779977
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -16.85865025325723
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -16.847683709124258
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -16.8476972821268
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -16.848835772322623
# 750 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 748, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 2}) | 2.193647826836498
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -16.843790917970257
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -16.849146833076478
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -16.834800413129532
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -16.842508694051315
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -16.770159557505316
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -16.782986470646563
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -16.828377085049073
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -16.828844822641628
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -16.813734268861676
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -16.848508713279898
# 1000 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 997, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 3}) | 2.2158679382227886
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -16.844157027586988
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -16.825595731283425
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -16.73925175953374
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -16.842147471524026
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -16.79806229544933
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -16.845401191829062
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -16.790834500425547
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -16.821627525408374
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -16.8371471991086
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -16.821881014497094
# 1250 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1246, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 4}) | 2.2236095341673434
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -17.823055571908448
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -17.40257125102654
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -17.875270580963573
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -17.789619446378023
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -17.849059452657645
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -17.791393423068158
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -17.835259589262634
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -17.898204477160544
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -17.878441821135308
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -17.751591233534626
# 1500 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1496, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 3, ('Z', 'Z', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 1}) | 1.2579285192079275
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -17.846324054351413
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -17.828496133999156
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -17.784634511864763
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -17.945667928525324
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -17.878134657368342
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -17.931553014502683
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -17.91975757869221
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -17.91221999721268
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -17.87771099012139
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -17.712700363213905
# 1750 | Counter({('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1745, ('X', 'X', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 4, ('Z', 'Z', 'X', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'X', 'Z'): 1}) | 1.1783108991926696
# Execution time =  06:47:07
