# %%
'''
(C) 2023 Renata Wong

Electronic structure problem with classical shadows, as presented in https://arxiv.org/abs/2103.07510
This code uses Qiskit as platform. 
The shadow is constructed based on derandomized Hamiltonian.
The molecules tested are: H2 (6-31s basis), LiH (sto3g basis), BeH2 (sto3g), H2O (sto3g), and NH3 (sto3g).
The coordinates for NH3 were taken from 'Algorithms for Computer Detection of Symmetry Elementsin Molecular Systems'. 
'''

import time
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, execute
from qiskit_aer.primitives import Estimator as AerEstimator 
from qiskit_aer import QasmSimulator

from qiskit.quantum_info import SparsePauliOp

from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.mappers import BravyiKitaevMapper, JordanWignerMapper, ParityMapper

from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import VQEUCCFactory
from qiskit.algorithms.minimum_eigensolvers import VQE
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA

# Estimator primitive is based on the Statevector construct = algebraic simulation
from qiskit.primitives import Estimator 
from qiskit.utils import algorithm_globals

from modified_derandomization import modified_derandomized_classical_shadow
from predicting_quantum_properties.data_acquisition_shadow import derandomized_classical_shadow
from predicting_quantum_properties.prediction_shadow import estimate_exp

import qiskit_nature
qiskit_nature.settings.use_pauli_sum_op = False
import h5py
H5PY_DEFAULT_READONLY=1

# %%
'''
DEFINING DRIVERS FOR THE MOLECULES
'''


H2_driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 0.735",
    basis="6-31g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

LiH_driver = PySCFDriver(
    atom="Li 0 0 0; H 0 0 1.599",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

BeH2_driver = PySCFDriver(
    atom="Be 0 0 0; H 0 0 1.3264; H 0 0 -1.3264",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

H2O_driver = PySCFDriver(
    atom="O 0.0 0.0 0.0; H 0.757 0.586 0.0; H -0.757 0.586 0.0",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

NH3_driver = PySCFDriver(
    atom="N 0 0 0; H 0 0 1.008000; H 0.950353 0 -0.336000; H -0.475176 -0.823029 -0.336000",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

# %%
'''
FORMATTING HAMILTONIAN
'''

def process_hamiltonian(hamiltonian, derandomize = False):

    hamiltonian_observables = []
    hamiltonian_coefficients = []

    for observable in hamiltonian.paulis:
        op_list = []
        for op_index, pauli_op in enumerate(observable):
            pauli_op = str(pauli_op)
            if pauli_op == 'I' or pauli_op == 'X' or pauli_op == 'Y' or pauli_op == 'Z':
                op_list.append((pauli_op, op_index))
        hamiltonian_observables.append(op_list)
    
    hamiltonian_coefficients = hamiltonian.coeffs.real
    
    system_size = len(hamiltonian_observables[0])

    # removing all occurrences of Pauli-I, for all-Pauli-I there is an empty list left
    # these observables are needed for estimate_exp()
    observables_xyze = []

    for observable in hamiltonian_observables:
        XYZE = []
        for pauli in observable:
            if pauli[0] != 'I':
                XYZE.append(pauli)
        observables_xyze.append(XYZE)   
    
    # derandomisation procedure requires that coefficients are non-negative
    if derandomize == True:
        absolute_coefficients = [abs(coeffcient) for coeffcient in hamiltonian_coefficients]

        # removing the empty list as well
        # these observables are needed for derandomisation procedure
        observables_xyz = []
        for idx, observable in enumerate(observables_xyze):
            if observable:
                observables_xyz.append(observable)
            else:
                absolute_coefficients.pop(idx)
        
        return system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients
    
    return system_size, observables_xyze, hamiltonian_coefficients








'''
COST FUNCTION AND HELPER FUNCTIONS
''' 

def basis_change_circuit(pauli_op):

    #   Generating circuit with just the basis change operators
    #
    #       pauli_op: n-qubit Pauli operator

    basis_change = QuantumCircuit(ansatz.num_qubits, ansatz.num_qubits)

    for idx, op in enumerate(pauli_op):
        
        if op == 'X':
            basis_change.h(idx)
        if op == 'Y':
            basis_change.h(idx)
            basis_change.p(-np.pi/2, idx)
            
    return basis_change

    
    


def ground_state_energy_from_shadow(operators, params):
    
    backend = QasmSimulator(method='statevector', shots=1)
    
    pauli_op_dict = Counter(tuple(x) for x in operators)    
    

    shadow = []
    for pauli_op in pauli_op_dict:
        
        qc = ansatz.bind_parameters(params)
        qc = qc.compose(basis_change_circuit(pauli_op))                                  
        qc.measure(reversed(range(system_size)), range(system_size))                      
        
        result = execute(qc, backend, shots=pauli_op_dict[pauli_op]).result()
        counts = result.get_counts()    # given in order q0 q1 ... qn-1 after register reversal in qc.measure
        
        for count in counts:
            for _ in range(counts[count]): # number of repeated measurement values

                output_str = list(count)   
                output = [int(i) for i in output_str]
                eigenvals = [x+1 if x == 0 else x-2 for x in output]
                snapshot = [(op, eigenval) for op, eigenval in zip(pauli_op, eigenvals)]
                
                shadow.append(snapshot)
    

    expectation_value = 0.0
    for term, weight in zip(observables_xyze, hamiltonian_coefficients):
        
        sum_product, match_count = estimate_exp(shadow, term)
        
        if match_count != 0:
            expectation_value += (weight * sum_product / match_count)

    return expectation_value

# %%
'''
EXPERIMENTS
'''

start_time = time.time()
all_molecules_rmse_errors = []



# CALCULATING FERMIONIC HAMILTONIAN AND CONVERTING TO QUBIT HAMILTONIAN

MOLECULES = ['LiH']

for molecule in MOLECULES:   
    
    rmse_errors = []
    
    if molecule == 'H2':
        problem = H2_driver.run()
    if molecule == 'LiH':
        problem = LiH_driver.run()
    if molecule == 'BeH2':
        problem = BeH2_driver.run()
    if molecule == 'H2O':
        problem = H2O_driver.run()
    if molecule == 'NH3':
        problem = NH3_driver.run()

    hamiltonian = problem.hamiltonian
    second_q_op = hamiltonian.second_q_op()

    bk_mapper = BravyiKitaevMapper() #(num_particles=problem.num_particles)  #BravyiKitaevMapper()
    bkencoded_hamiltonian = bk_mapper.map(second_q_op)
    #print('Qubit Hamiltonian in Bravyi-Kitaev encoding', bkencoded_hamiltonian)


    # process the Hamiltonian to obtain properly formatted data
    hamiltonian_data = process_hamiltonian(bkencoded_hamiltonian, derandomize = True)
    system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients = hamiltonian_data

    '''
    VARIATIONAL ANSATZ
    '''
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        bk_mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            bk_mapper,
        ),
    )
    
    '''
    Running VQE on the Hamiltonian obtained from PySCFDriver using Statevector simulator (Estimator primitive)
    '''
    #estimator = Estimator()
    # If shots = None, it calculates the exact expectation values. Otherwise, it samples from normal distributions 
    # with standard errors as standard deviations using normal distribution approximation.
    #estimator.set_options(shots = None)
    #estimator = AerEstimator()
    #estimator.set_options(approximation=False, shots=None)
    
    #vqe_solver = VQE(estimator, ansatz, SLSQP())
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    vqe_solver.initial_point = np.zeros(ansatz.num_parameters)

    calc = GroundStateEigensolver(bk_mapper, vqe_solver)
    result = calc.solve(problem)
    print(result.raw_result)
    


    #print('NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR\n')
    measurement_range = [50, 250, 500, 750, 1000, 1250, 1500, 1750]   

    for num_operators in measurement_range:   

        derandomized_hamiltonian = derandomized_classical_shadow(observables_xyz, 50, 
                                                                          system_size, weight=absolute_coefficients)

        tuples = (tuple(pauli) for pauli in derandomized_hamiltonian)
        counts = Counter(tuples)
        print('Original derandomized Hamiltonian', counts)
        
        # derandomized classical shadow will usually either undergenerate or overgenerate derandomized operators
        # adjusting for this issue: 
        
        while sum(counts.values()) != num_operators:
            for key, value in zip(counts.keys(), counts.values()):
                sum_counts = sum(counts.values())
                if sum_counts == num_operators:
                    break
                if sum_counts < num_operators:
                    # generate additional operators from the existing ones by increasing the number of counts
                    counts[key] += 1
                if sum_counts > num_operators:
                    # remove the element with highest count
                    max_element_key = [k for k, v in counts.items() if v == max(counts.values())][0]
                    counts[max_element_key] -= 1
    
        print('Size-adjusted derandomized Hamiltonian', counts)
        
        # translate the Counter to a set of derandomized operators
        new_derandomized_hamiltonian = []
        for key, value in counts.items():
            for _ in range(value):
                new_derandomized_hamiltonian.append(list(key))
        #print('Size-adjusted derandomized Hamiltonian', new_derandomized_hamiltonian)
        
        
        expectation_values = []
        num_experiments = 10   

        
        for iteration in range(num_experiments):

            expectation_value = ground_state_energy_from_shadow(new_derandomized_hamiltonian, result.raw_result.optimal_point)
            expectation_values.append(expectation_value)

            print("EXPERIMENT {}: GROUND STATE ENERGY FOUND = {}".format(iteration, expectation_value))


        rmse_derandomised_cs = np.sqrt(np.sum([(expectation_values[i] - result.raw_result.optimal_value)**2 
                                               for i in range(num_experiments)])/num_experiments)

        rmse_errors.append(rmse_derandomised_cs)

        print('{} | {} | {}'.format(num_operators, counts, rmse_derandomised_cs))
        
    all_molecules_rmse_errors.append(rmse_errors)
    
    elapsed_time = time.time() - start_time
    print("Execution time = ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# {   'aux_operators_evaluated': {   'AngularMomentum': (   2.938301130184229e-10,
#                                                           {}),
#                                    'Magnetization': (-0.0, {}),
#                                    'ParticleNumber': (3.9999999999987024, {}),
#                                    'XDipole': (-3.034179059947031e-05, {}),
#                                    'YDipole': (-2.2572342521564917e-05, {}),
#                                    'ZDipole': (4.839730454780564, {})},
#     'cost_function_evals': 1035,
#     'eigenvalue': -8.875157359200585,
#     'optimal_circuit': <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x7faae41f7bd0>,
#     'optimal_parameters': {   ParameterVectorElement(t[58]): -0.03595576168319273,
#                               ParameterVectorElement(t[59]): 3.900167552778319e-07,
#                               ParameterVectorElement(t[60]): 1.3808099759783417e-06,
#                               ParameterVectorElement(t[61]): 0.05955858654107352,
#                               ParameterVectorElement(t[62]): -5.460456645421732e-07,
#                               ParameterVectorElement(t[63]): -0.0030854362710719917,
#                               ParameterVectorElement(t[64]): 3.1198802022012427e-07,
#                               ParameterVectorElement(t[65]): 6.364011993260614e-07,
#                               ParameterVectorElement(t[66]): 1.8009002938771571e-06,
#                               ParameterVectorElement(t[67]): -0.026888867947630343,
#                               ParameterVectorElement(t[69]): -1.5867783390466043e-06,
#                               ParameterVectorElement(t[70]): 4.1965412877551115e-07,
#                               ParameterVectorElement(t[71]): -1.7353626186271888e-07,
#                               ParameterVectorElement(t[72]): -0.0030865904300820517,
#                               ParameterVectorElement(t[73]): -9.721233727573465e-08,
#                               ParameterVectorElement(t[74]): 8.708816856336869e-07,
#                               ParameterVectorElement(t[75]): 6.455716780377404e-07,
#                               ParameterVectorElement(t[76]): -0.02689758282526573,
#                               ParameterVectorElement(t[77]): -1.6158741822168464e-06,
#                               ParameterVectorElement(t[78]): -0.00035490334311087603,
#                               ParameterVectorElement(t[79]): 5.6010570601535045e-08,
#                               ParameterVectorElement(t[80]): 2.996870527263175e-07,
#                               ParameterVectorElement(t[81]): -0.0002947406490273252,
#                               ParameterVectorElement(t[82]): 0.05970187418553534,
#                               ParameterVectorElement(t[83]): -1.0442880921764201e-06,
#                               ParameterVectorElement(t[84]): -1.6701309832246733e-06,
#                               ParameterVectorElement(t[85]): -0.11488580934796531,
#                               ParameterVectorElement(t[86]): 8.946352026258934e-09,
#                               ParameterVectorElement(t[87]): -1.838774878777855e-07,
#                               ParameterVectorElement(t[88]): 0.0006789010862788196,
#                               ParameterVectorElement(t[89]): -5.797758179975941e-08,
#                               ParameterVectorElement(t[90]): 3.3156371742376574e-07,
#                               ParameterVectorElement(t[91]): 4.2770754100779375e-07,
#                               ParameterVectorElement(t[68]): 5.210040096248408e-07,
#                               ParameterVectorElement(t[2]): 9.583384862571775e-07,
#                               ParameterVectorElement(t[3]): 0.0006099805684558482,
#                               ParameterVectorElement(t[1]): 9.231814176923446e-08,
#                               ParameterVectorElement(t[4]): -0.0386347758561116,
#                               ParameterVectorElement(t[5]): 6.9774888765807355e-06,
#                               ParameterVectorElement(t[6]): 7.080850525232032e-06,
#                               ParameterVectorElement(t[7]): -0.003812991416503369,
#                               ParameterVectorElement(t[8]): -0.0002130925796370568,
#                               ParameterVectorElement(t[9]): 3.7024464009542505e-07,
#                               ParameterVectorElement(t[10]): 2.1265529859320718e-07,
#                               ParameterVectorElement(t[11]): 0.0006096469497665772,
#                               ParameterVectorElement(t[12]): -0.038622984748469695,
#                               ParameterVectorElement(t[13]): 5.11946640110703e-06,
#                               ParameterVectorElement(t[14]): 6.054403598126918e-06,
#                               ParameterVectorElement(t[15]): -0.0038155873542656074,
#                               ParameterVectorElement(t[16]): 3.298055430718752e-07,
#                               ParameterVectorElement(t[17]): 1.0384948474618885e-06,
#                               ParameterVectorElement(t[18]): 0.0006697081531978855,
#                               ParameterVectorElement(t[19]): -0.0038035144413791546,
#                               ParameterVectorElement(t[20]): -1.4102796182701193e-06,
#                               ParameterVectorElement(t[21]): -2.0338320060753743e-07,
#                               ParameterVectorElement(t[22]): 0.0001771827277420316,
#                               ParameterVectorElement(t[23]): -0.00017602575174330463,
#                               ParameterVectorElement(t[24]): 5.545615276600952e-08,
#                               ParameterVectorElement(t[25]): 5.735494736527758e-07,
#                               ParameterVectorElement(t[26]): -0.00035347371322190366,
#                               ParameterVectorElement(t[27]): 4.212415883964021e-08,
#                               ParameterVectorElement(t[28]): 1.518886013831935e-07,
#                               ParameterVectorElement(t[29]): -1.2583365979643614e-06,
#                               ParameterVectorElement(t[30]): -0.0018255334216050218,
#                               ParameterVectorElement(t[31]): 1.9292498107784418e-07,
#                               ParameterVectorElement(t[32]): 5.8571732855652e-07,
#                               ParameterVectorElement(t[33]): 2.376156529018905e-09,
#                               ParameterVectorElement(t[34]): -0.003076059619177916,
#                               ParameterVectorElement(t[35]): -1.2083369713218777e-07,
#                               ParameterVectorElement(t[36]): 4.3569767286275763e-07,
#                               ParameterVectorElement(t[37]): -7.563529197901753e-07,
#                               ParameterVectorElement(t[38]): -2.2999015373004982e-06,
#                               ParameterVectorElement(t[39]): -2.1298036223251158e-07,
#                               ParameterVectorElement(t[40]): -0.0018250149673559697,
#                               ParameterVectorElement(t[41]): 6.118060747519357e-07,
#                               ParameterVectorElement(t[42]): 3.671410776603688e-07,
#                               ParameterVectorElement(t[43]): 2.977556498550774e-07,
#                               ParameterVectorElement(t[44]): -0.00307611457325385,
#                               ParameterVectorElement(t[45]): 8.819902305882909e-07,
#                               ParameterVectorElement(t[46]): 0.0001721458318453885,
#                               ParameterVectorElement(t[47]): -1.2070345053099507e-06,
#                               ParameterVectorElement(t[48]): -2.841014837682913e-07,
#                               ParameterVectorElement(t[49]): -0.0010699066796354747,
#                               ParameterVectorElement(t[50]): -0.0010206066873389877,
#                               ParameterVectorElement(t[51]): 4.432532156630208e-08,
#                               ParameterVectorElement(t[52]): 2.9943314065598417e-07,
#                               ParameterVectorElement(t[53]): -0.0002983244941369814,
#                               ParameterVectorElement(t[54]): -0.00017872040884040188,
#                               ParameterVectorElement(t[55]): 8.841243870126629e-07,
#                               ParameterVectorElement(t[56]): 3.9308147912376987e-07,
#                               ParameterVectorElement(t[57]): -0.001021163324914385,
#                               ParameterVectorElement(t[0]): -0.00021480478991173563},
#     'optimal_point': array([-2.14804790e-04,  9.23181418e-08,  9.58338486e-07,  6.09980568e-04,
#        -3.86347759e-02,  6.97748888e-06,  7.08085053e-06, -3.81299142e-03,
#        -2.13092580e-04,  3.70244640e-07,  2.12655299e-07,  6.09646950e-04,
#        -3.86229847e-02,  5.11946640e-06,  6.05440360e-06, -3.81558735e-03,
#         3.29805543e-07,  1.03849485e-06,  6.69708153e-04, -3.80351444e-03,
#        -1.41027962e-06, -2.03383201e-07,  1.77182728e-04, -1.76025752e-04,
#         5.54561528e-08,  5.73549474e-07, -3.53473713e-04,  4.21241588e-08,
#         1.51888601e-07, -1.25833660e-06, -1.82553342e-03,  1.92924981e-07,
#         5.85717329e-07,  2.37615653e-09, -3.07605962e-03, -1.20833697e-07,
#         4.35697673e-07, -7.56352920e-07, -2.29990154e-06, -2.12980362e-07,
#        -1.82501497e-03,  6.11806075e-07,  3.67141078e-07,  2.97755650e-07,
#        -3.07611457e-03,  8.81990231e-07,  1.72145832e-04, -1.20703451e-06,
#        -2.84101484e-07, -1.06990668e-03, -1.02060669e-03,  4.43253216e-08,
#         2.99433141e-07, -2.98324494e-04, -1.78720409e-04,  8.84124387e-07,
#         3.93081479e-07, -1.02116332e-03, -3.59557617e-02,  3.90016755e-07,
#         1.38080998e-06,  5.95585865e-02, -5.46045665e-07, -3.08543627e-03,
#         3.11988020e-07,  6.36401199e-07,  1.80090029e-06, -2.68888679e-02,
#         5.21004010e-07, -1.58677834e-06,  4.19654129e-07, -1.73536262e-07,
#        -3.08659043e-03, -9.72123373e-08,  8.70881686e-07,  6.45571678e-07,
#        -2.68975828e-02, -1.61587418e-06, -3.54903343e-04,  5.60105706e-08,
#         2.99687053e-07, -2.94740649e-04,  5.97018742e-02, -1.04428809e-06,
#        -1.67013098e-06, -1.14885809e-01,  8.94635203e-09, -1.83877488e-07,
#         6.78901086e-04, -5.79775818e-08,  3.31563717e-07,  4.27707541e-07]),
#     'optimal_value': -8.875157359200585,
#     'optimizer_evals': None,
#     'optimizer_result': <qiskit.algorithms.optimizers.optimizer.OptimizerResult object at 0x7faa8040fc90>,
#     'optimizer_time': 3596.047184944153}
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 21, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.746545205517513
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.900693846051706
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.725516010628107
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.83359676563901
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.664511396531806
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.534102513828863
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.923470165070059
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.875728188924484
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.920884216340205
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.89939820274323
# 50 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 21, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1}) | 0.1438805617631318
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 15, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 11, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 11, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 11, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 10, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 10, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 10, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 10})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.791060526637702
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.858758145633878
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.826001064237987
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.82766846567763
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.815862831402105
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.841161997233515
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.836048479745525
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.81314109691607
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.748551961540048
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.7604458600553
# 250 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 15, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 11, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 11, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 11, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 10, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 10, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 10, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 10}) | 0.07158732391298837
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 45, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 25, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 23, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 23, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 23, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 22, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 22, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 22, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 22, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 22, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 22})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.809566746380286
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.815428562231629
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.83189356704475
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.82508110920752
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.818532652482087
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.81747250158962
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.805529422317308
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.822186379107498
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.833814130598315
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.872727737938234
# 500 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 45, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 25, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 23, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 23, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 23, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 22, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 22, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 22, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 22, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 22, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 22}) | 0.053058537812973976
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 39, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 37, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 35, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 35, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 35, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 34, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 34, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 34, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 34, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 34, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 34, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 34})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.797268334252129
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.847472718164711
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.811702053692114
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.795402480452626
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.806250960263364
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.827146034590548
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.806066363208146
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.782571976267969
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.813861965441765
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.815592969375608
# 750 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 39, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 37, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 35, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 35, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 35, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 34, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 34, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 34, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 34, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 34, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 34, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 34, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 34}) | 0.06702566361817298
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 69, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 51, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 49, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 47, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 46, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 46, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 46, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 46, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 46, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 46, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 46})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.843807163212658
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.797194060171279
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.798855854517464
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.81553754638808
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.815152919529483
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.81640810592247
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.81593942645645
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.834568400971873
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.810924472201998
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.845189489380251
# 1000 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 69, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 51, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 49, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 47, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 46, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 46, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 46, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 46, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 46, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 46, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 46, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 46, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 46, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 46}) | 0.058023895167441934
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 81, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 63, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 60, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 59, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 59, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 58, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 58, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 58, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 58, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 58, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 58})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.79845736387369
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.815814539766421
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.806178046323346
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.841230026361576
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.825029682387694
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.840841061931084
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.803148281494497
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.834966597586122
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.80962059761319
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.810502844575632
# 1250 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 81, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 63, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 60, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 59, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 59, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 58, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 58, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 58, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 58, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 58, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 58, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 58, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 58, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 58}) | 0.05854907277921381
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 92, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 75, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 72, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 71, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 70, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 70, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 70, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 70, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 70, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 70, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 70})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.822276659847695
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.813802970417797
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.809749335682307
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.801653294609004
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.82802339495533
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.842838017179055
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.812082162598832
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.81250151361869
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.805402880998935
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.80321110924293
# 1500 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 92, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 75, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 72, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 71, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 70, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 70, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 70, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 70, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 70, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 70, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 70, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 70, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 70, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 70}) | 0.06119977321630785
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 24, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 2, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 2, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 104, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 86, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 84, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 83, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 82, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 82, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 81})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -8.829263848426015
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -8.817433851284463
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -8.835200945076698
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -8.83345653721242
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -8.833831053538326
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -8.802295712271617
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -8.83565907387663
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -8.835450491948665
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -8.826188711112371
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -8.834751038533005
# 1750 | Counter({('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X'): 104, ('Z', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 86, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 84, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 83, ('X', 'Y', 'Y', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X', 'Z', 'X'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'X'): 82, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Y', 'Z', 'Z', 'Z', 'Y'): 82, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 82, ('Z', 'Y', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'X', 'Z', 'Z', 'Y'): 82, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 82, ('Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 82, ('Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Z'): 82, ('Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 81}) | 0.047914218672907176
# Execution time =  03:38:01

# %%
import matplotlib.pyplot as plt 
points = measurement_range 
num_points = len(points)

plt.plot([i for i in points], [rmse_errors[i] for i in range(num_points)], 'r', label='derandomized classical shadow')
plt.xlabel('Number of measurements')
plt.ylabel('Average RMSE error')
plt.legend(loc=1)
