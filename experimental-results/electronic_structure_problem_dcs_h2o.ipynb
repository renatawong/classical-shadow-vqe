# %%
'''
(C) 2023 Renata Wong

Electronic structure problem with classical shadows, as presented in https://arxiv.org/abs/2103.07510
This code uses Qiskit as platform. 
The shadow is constructed based on derandomized Hamiltonian.
The molecules tested are: H2 (6-31s basis), LiH (sto3g basis), BeH2 (sto3g), H2O (sto3g), and NH3 (sto3g).
The coordinates for NH3 were taken from 'Algorithms for Computer Detection of Symmetry Elementsin Molecular Systems'. 
'''

import time
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, execute
from qiskit_aer.primitives import Estimator as AerEstimator 
from qiskit_aer import QasmSimulator

from qiskit.quantum_info import SparsePauliOp

from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.mappers import BravyiKitaevMapper, JordanWignerMapper, ParityMapper

from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import VQEUCCFactory
from qiskit.algorithms.minimum_eigensolvers import VQE
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA

# Estimator primitive is based on the Statevector construct = algebraic simulation
from qiskit.primitives import Estimator 
from qiskit.utils import algorithm_globals

from modified_derandomization import modified_derandomized_classical_shadow
from predicting_quantum_properties.data_acquisition_shadow import derandomized_classical_shadow
from predicting_quantum_properties.prediction_shadow import estimate_exp

import qiskit_nature
qiskit_nature.settings.use_pauli_sum_op = False
import h5py
H5PY_DEFAULT_READONLY=1

# %%
'''
DEFINING DRIVERS FOR THE MOLECULES
'''


H2_driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 0.735",
    basis="6-31g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

LiH_driver = PySCFDriver(
    atom="Li 0 0 0; H 0 0 1.599",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

BeH2_driver = PySCFDriver(
    atom="Be 0 0 0; H 0 0 1.3264; H 0 0 -1.3264",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

H2O_driver = PySCFDriver(
    atom="O 0.0 0.0 0.0; H 0.757 0.586 0.0; H -0.757 0.586 0.0",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

NH3_driver = PySCFDriver(
    atom="N 0 0 0; H 0 0 1.008000; H 0.950353 0 -0.336000; H -0.475176 -0.823029 -0.336000",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

# %%
'''
FORMATTING HAMILTONIAN
'''

def process_hamiltonian(hamiltonian, derandomize = False):

    hamiltonian_observables = []
    hamiltonian_coefficients = []

    for observable in hamiltonian.paulis:
        op_list = []
        for op_index, pauli_op in enumerate(observable):
            pauli_op = str(pauli_op)
            if pauli_op == 'I' or pauli_op == 'X' or pauli_op == 'Y' or pauli_op == 'Z':
                op_list.append((pauli_op, op_index))
        hamiltonian_observables.append(op_list)
    
    hamiltonian_coefficients = hamiltonian.coeffs.real
    
    system_size = len(hamiltonian_observables[0])

    # removing all occurrences of Pauli-I, for all-Pauli-I there is an empty list left
    # these observables are needed for estimate_exp()
    observables_xyze = []

    for observable in hamiltonian_observables:
        XYZE = []
        for pauli in observable:
            if pauli[0] != 'I':
                XYZE.append(pauli)
        observables_xyze.append(XYZE)   
    
    # derandomisation procedure requires that coefficients are non-negative
    if derandomize == True:
        absolute_coefficients = [abs(coeffcient) for coeffcient in hamiltonian_coefficients]

        # removing the empty list as well
        # these observables are needed for derandomisation procedure
        observables_xyz = []
        for idx, observable in enumerate(observables_xyze):
            if observable:
                observables_xyz.append(observable)
            else:
                absolute_coefficients.pop(idx)
        
        return system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients
    
    return system_size, observables_xyze, hamiltonian_coefficients








'''
COST FUNCTION AND HELPER FUNCTIONS
''' 

def basis_change_circuit(pauli_op):

    #   Generating circuit with just the basis change operators
    #
    #       pauli_op: n-qubit Pauli operator

    basis_change = QuantumCircuit(ansatz.num_qubits, ansatz.num_qubits)

    for idx, op in enumerate(pauli_op):
        
        if op == 'X':
            basis_change.h(idx)
        if op == 'Y':
            basis_change.h(idx)
            basis_change.p(-np.pi/2, idx)
            
    return basis_change

    
    


def ground_state_energy_from_shadow(operators, params):
    
    backend = QasmSimulator(method='statevector', shots=1)
    
    pauli_op_dict = Counter(tuple(x) for x in operators)    
    

    shadow = []
    for pauli_op in pauli_op_dict:
        
        qc = ansatz.bind_parameters(params)
        qc = qc.compose(basis_change_circuit(pauli_op))                                  
        qc.measure(reversed(range(system_size)), range(system_size))                      
        
        result = execute(qc, backend, shots=pauli_op_dict[pauli_op]).result()
        counts = result.get_counts()    # given in order q0 q1 ... qn-1 after register reversal in qc.measure
        
        for count in counts:
            for _ in range(counts[count]): # number of repeated measurement values

                output_str = list(count)   
                output = [int(i) for i in output_str]
                eigenvals = [x+1 if x == 0 else x-2 for x in output]
                snapshot = [(op, eigenval) for op, eigenval in zip(pauli_op, eigenvals)]
                
                shadow.append(snapshot)
    

    expectation_value = 0.0
    for term, weight in zip(observables_xyze, hamiltonian_coefficients):
        
        sum_product, match_count = estimate_exp(shadow, term)
        
        if match_count != 0:
            expectation_value += (weight * sum_product / match_count)

    return expectation_value

# %%
'''
EXPERIMENTS
'''

start_time = time.time()
all_molecules_rmse_errors = []



# CALCULATING FERMIONIC HAMILTONIAN AND CONVERTING TO QUBIT HAMILTONIAN

MOLECULES = ['H2O']

for molecule in MOLECULES:   
    
    rmse_errors = []
    
    if molecule == 'H2':
        problem = H2_driver.run()
    if molecule == 'LiH':
        problem = LiH_driver.run()
    if molecule == 'BeH2':
        problem = BeH2_driver.run()
    if molecule == 'H2O':
        problem = H2O_driver.run()
    if molecule == 'NH3':
        problem = NH3_driver.run()

    hamiltonian = problem.hamiltonian
    second_q_op = hamiltonian.second_q_op()

    bk_mapper = BravyiKitaevMapper()
    bkencoded_hamiltonian = bk_mapper.map(second_q_op)
    #print('Qubit Hamiltonian in Bravyi-Kitaev encoding', bkencoded_hamiltonian)


    # process the Hamiltonian to obtain properly formatted data
    hamiltonian_data = process_hamiltonian(bkencoded_hamiltonian, derandomize = True)
    system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients = hamiltonian_data

    '''
    VARIATIONAL ANSATZ
    '''
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        bk_mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            bk_mapper,
        ),
    )
    
    '''
    Running VQE on the Hamiltonian obtained from PySCFDriver using Statevector simulator (Estimator primitive)
    '''
    #estimator = Estimator()
    # If shots = None, it calculates the exact expectation values. Otherwise, it samples from normal distributions 
    # with standard errors as standard deviations using normal distribution approximation.
    #estimator.set_options(shots = None)
    #estimator = AerEstimator()
    #estimator.set_options(approximation=True, shots=None)
    
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    vqe_solver.initial_point = np.zeros(ansatz.num_parameters)

    calc = GroundStateEigensolver(bk_mapper, vqe_solver)
    result = calc.solve(problem)
    print(result.raw_result)
    


    #print('NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR\n')
    measurement_range = [50, 250, 500, 750, 1000, 1250, 1500, 1750]   

    for num_operators in measurement_range:   

        derandomized_hamiltonian = derandomized_classical_shadow(observables_xyz, 50, 
                                                                          system_size, weight=absolute_coefficients)

        tuples = (tuple(pauli) for pauli in derandomized_hamiltonian)
        counts = Counter(tuples)
        print('Original derandomized Hamiltonian', counts)
        
        # derandomized classical shadow will usually either undergenerate or overgenerate derandomized operators
        # adjusting for this issue: 
        
        while sum(counts.values()) != num_operators:
            for key, value in zip(counts.keys(), counts.values()):
                sum_counts = sum(counts.values())
                if sum_counts == num_operators:
                    break
                if sum_counts < num_operators:
                    # generate additional operators from the existing ones by increasing the number of counts
                    counts[key] += 1
                if sum_counts > num_operators:
                    # remove the element with highest count
                    max_element_key = [k for k, v in counts.items() if v == max(counts.values())][0]
                    counts[max_element_key] -= 1
    
        print('Size-adjusted derandomized Hamiltonian', counts)
        
        # translate the Counter to a set of derandomized operators
        new_derandomized_hamiltonian = []
        for key, value in counts.items():
            for _ in range(value):
                new_derandomized_hamiltonian.append(list(key))
        #print('Size-adjusted derandomized Hamiltonian', new_derandomized_hamiltonian)
        
        
        expectation_values = []
        num_experiments = 10   

        
        for iteration in range(num_experiments):

            expectation_value = ground_state_energy_from_shadow(new_derandomized_hamiltonian, result.raw_result.optimal_point)
            expectation_values.append(expectation_value)

            print("EXPERIMENT {}: GROUND STATE ENERGY FOUND = {}".format(iteration, expectation_value))


        rmse_derandomised_cs = np.sqrt(np.sum([(expectation_values[i] - result.raw_result.optimal_value)**2 
                                               for i in range(num_experiments)])/num_experiments)

        rmse_errors.append(rmse_derandomised_cs)

        print('{} | {} | {}'.format(num_operators, counts, rmse_derandomised_cs))
        
    all_molecules_rmse_errors.append(rmse_errors)
    
    elapsed_time = time.time() - start_time
    print("Execution time = ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# {   'aux_operators_evaluated': {   'AngularMomentum': (   1.8266913301423493e-08,
#                                                           {}),
#                                    'Magnetization': (0.0, {}),
#                                    'ParticleNumber': (9.999999999987274, {}),
#                                    'XDipole': (5.7148216079354024e-05, {}),
#                                    'YDipole': (1.5799188259533699, {}),
#                                    'ZDipole': (-1.8803777263290326e-06, {})},
#     'cost_function_evals': 1854,
#     'eigenvalue': -84.20624898647324,
#     'optimal_circuit': <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x7fa6432681d0>,
#     'optimal_parameters': {   ParameterVectorElement(t[1]): 3.230818858835462e-06,
#                               ParameterVectorElement(t[0]): 7.34984768770234e-05,
#                               ParameterVectorElement(t[4]): 1.4435050827591916e-05,
#                               ParameterVectorElement(t[3]): 6.379659508562009e-06,
#                               ParameterVectorElement(t[6]): 0.01282753469191646,
#                               ParameterVectorElement(t[5]): 0.0032542644663230754,
#                               ParameterVectorElement(t[7]): 7.770640003310701e-08,
#                               ParameterVectorElement(t[8]): 7.925170934059092e-06,
#                               ParameterVectorElement(t[9]): 1.5499052191765373e-05,
#                               ParameterVectorElement(t[10]): 8.432958618930972e-05,
#                               ParameterVectorElement(t[11]): 2.6783390119195292e-06,
#                               ParameterVectorElement(t[12]): -0.0002644018703309252,
#                               ParameterVectorElement(t[13]): 1.0007500830570307e-05,
#                               ParameterVectorElement(t[14]): 1.4893537762258778e-05,
#                               ParameterVectorElement(t[15]): 0.003209650098744833,
#                               ParameterVectorElement(t[16]): 0.012805633738527849,
#                               ParameterVectorElement(t[17]): 9.397215880860468e-06,
#                               ParameterVectorElement(t[18]): 1.180609650419493e-05,
#                               ParameterVectorElement(t[19]): 8.156828033464006e-06,
#                               ParameterVectorElement(t[20]): 3.9817232002327416e-07,
#                               ParameterVectorElement(t[21]): 0.0005087986199191652,
#                               ParameterVectorElement(t[22]): 1.5409113666491469e-06,
#                               ParameterVectorElement(t[23]): 1.885586659250522e-06,
#                               ParameterVectorElement(t[24]): -0.0006705223515807585,
#                               ParameterVectorElement(t[25]): 3.164423888140896e-05,
#                               ParameterVectorElement(t[26]): -0.00027662401351063353,
#                               ParameterVectorElement(t[27]): 2.2544733772835524e-06,
#                               ParameterVectorElement(t[28]): -1.7753028323165242e-06,
#                               ParameterVectorElement(t[29]): 0.00025483408251737423,
#                               ParameterVectorElement(t[30]): -0.00011841222810798972,
#                               ParameterVectorElement(t[31]): 1.431701850215113e-06,
#                               ParameterVectorElement(t[32]): 7.184914399973632e-07,
#                               ParameterVectorElement(t[33]): 1.2737884853815191e-06,
#                               ParameterVectorElement(t[34]): -2.3628216168949038e-05,
#                               ParameterVectorElement(t[35]): -0.0004328828677162719,
#                               ParameterVectorElement(t[36]): -4.336086264950028e-07,
#                               ParameterVectorElement(t[37]): -0.0007249027982178879,
#                               ParameterVectorElement(t[38]): -0.0002587270606176581,
#                               ParameterVectorElement(t[39]): 7.115311245642926e-07,
#                               ParameterVectorElement(t[40]): 1.954937060835144e-07,
#                               ParameterVectorElement(t[41]): 0.0005520514459674252,
#                               ParameterVectorElement(t[42]): 2.7416609004397195e-07,
#                               ParameterVectorElement(t[43]): 2.5894192798111224e-07,
#                               ParameterVectorElement(t[44]): -0.010801827919247822,
#                               ParameterVectorElement(t[45]): 8.883406519220395e-06,
#                               ParameterVectorElement(t[46]): 1.2729494951076838e-05,
#                               ParameterVectorElement(t[47]): -0.0002708514770142422,
#                               ParameterVectorElement(t[48]): 1.198778716836333e-06,
#                               ParameterVectorElement(t[49]): -0.03218455168297854,
#                               ParameterVectorElement(t[50]): -2.594769159699726e-06,
#                               ParameterVectorElement(t[52]): -0.031267157103579836,
#                               ParameterVectorElement(t[51]): 1.0230345963290453e-05,
#                               ParameterVectorElement(t[55]): -3.388452875737386e-07,
#                               ParameterVectorElement(t[54]): 4.6966918744454676e-06,
#                               ParameterVectorElement(t[59]): -2.5012955204665503e-06,
#                               ParameterVectorElement(t[53]): -0.033110324636897434,
#                               ParameterVectorElement(t[61]): -0.02035766631827513,
#                               ParameterVectorElement(t[56]): 9.512362022532856e-07,
#                               ParameterVectorElement(t[70]): -0.0002537544701882126,
#                               ParameterVectorElement(t[58]): -0.0007477516986336906,
#                               ParameterVectorElement(t[62]): 3.272635344000387e-09,
#                               ParameterVectorElement(t[60]): -0.016659691899564042,
#                               ParameterVectorElement(t[89]): 1.8296414584374462e-05,
#                               ParameterVectorElement(t[57]): 6.26060637070721e-07,
#                               ParameterVectorElement(t[66]): 5.588438503754185e-06,
#                               ParameterVectorElement(t[78]): 7.546105986888506e-06,
#                               ParameterVectorElement(t[63]): 7.070253726709031e-06,
#                               ParameterVectorElement(t[65]): 3.673082595849088e-06,
#                               ParameterVectorElement(t[64]): 0.0036686270877522116,
#                               ParameterVectorElement(t[69]): -5.249849231488808e-07,
#                               ParameterVectorElement(t[68]): 5.236691864443293e-06,
#                               ParameterVectorElement(t[67]): 0.012539618295460091,
#                               ParameterVectorElement(t[74]): 3.987859634870016e-06,
#                               ParameterVectorElement(t[73]): -0.04341855078542686,
#                               ParameterVectorElement(t[72]): -0.02049275147205027,
#                               ParameterVectorElement(t[71]): 6.568258893208819e-06,
#                               ParameterVectorElement(t[75]): 5.563276184381087e-06,
#                               ParameterVectorElement(t[77]): 1.0753011795885649e-05,
#                               ParameterVectorElement(t[76]): -0.03459525165351442,
#                               ParameterVectorElement(t[88]): 1.6416319381743847e-06,
#                               ParameterVectorElement(t[82]): 5.992944537238407e-06,
#                               ParameterVectorElement(t[81]): -0.03130957025549503,
#                               ParameterVectorElement(t[80]): -6.56026514108935e-08,
#                               ParameterVectorElement(t[84]): -0.07795557166950255,
#                               ParameterVectorElement(t[87]): 1.0688503150625839e-05,
#                               ParameterVectorElement(t[79]): 0.00026079745079785413,
#                               ParameterVectorElement(t[85]): -0.046996320793861936,
#                               ParameterVectorElement(t[83]): 7.83600992002389e-06,
#                               ParameterVectorElement(t[90]): -0.00010067932086016785,
#                               ParameterVectorElement(t[86]): 6.477973566763219e-06,
#                               ParameterVectorElement(t[92]): -0.0332054147403969,
#                               ParameterVectorElement(t[91]): -6.132827936892857e-07,
#                               ParameterVectorElement(t[95]): -0.047029306319714255,
#                               ParameterVectorElement(t[97]): 4.515058762008036e-06,
#                               ParameterVectorElement(t[96]): -0.04644841632470158,
#                               ParameterVectorElement(t[93]): 2.802160088193266e-06,
#                               ParameterVectorElement(t[100]): -2.213729139081319e-06,
#                               ParameterVectorElement(t[103]): 0.0036991537870405657,
#                               ParameterVectorElement(t[94]): 1.2871413649571421e-05,
#                               ParameterVectorElement(t[99]): 7.874193810079633e-06,
#                               ParameterVectorElement(t[102]): 6.382848304280872e-06,
#                               ParameterVectorElement(t[105]): 7.676942637626818e-06,
#                               ParameterVectorElement(t[115]): 3.6343223396305334e-06,
#                               ParameterVectorElement(t[98]): 8.17965644683402e-06,
#                               ParameterVectorElement(t[104]): -0.03467218432694743,
#                               ParameterVectorElement(t[106]): -8.134390581600766e-07,
#                               ParameterVectorElement(t[101]): 0.0005218282377849397,
#                               ParameterVectorElement(t[119]): 6.675146376271467e-06,
#                               ParameterVectorElement(t[110]): 1.8466299191156866e-07,
#                               ParameterVectorElement(t[109]): 9.84335539003082e-06,
#                               ParameterVectorElement(t[108]): 4.929869695966341e-06,
#                               ParameterVectorElement(t[107]): -0.041824179977736,
#                               ParameterVectorElement(t[114]): 3.752494937668581e-06,
#                               ParameterVectorElement(t[113]): 5.145054264454044e-06,
#                               ParameterVectorElement(t[112]): 3.778907840667328e-06,
#                               ParameterVectorElement(t[111]): 7.615845443378936e-08,
#                               ParameterVectorElement(t[117]): 9.98832548496086e-07,
#                               ParameterVectorElement(t[121]): 1.2467488655894837e-06,
#                               ParameterVectorElement(t[118]): -0.02632527043347287,
#                               ParameterVectorElement(t[127]): 1.7992135019723189e-06,
#                               ParameterVectorElement(t[116]): 1.8844727349454138e-06,
#                               ParameterVectorElement(t[126]): 5.653055317288231e-07,
#                               ParameterVectorElement(t[122]): 2.115266496705595e-06,
#                               ParameterVectorElement(t[125]): -3.138855961381532e-07,
#                               ParameterVectorElement(t[124]): 4.021431234852046e-06,
#                               ParameterVectorElement(t[130]): 2.0423694394816086e-07,
#                               ParameterVectorElement(t[129]): -0.010481115010717534,
#                               ParameterVectorElement(t[120]): 2.928299351922259e-07,
#                               ParameterVectorElement(t[133]): 6.56511642954758e-07,
#                               ParameterVectorElement(t[123]): 3.512888099017587e-06,
#                               ParameterVectorElement(t[128]): 1.5485119095852555e-07,
#                               ParameterVectorElement(t[131]): 0.00046847404044696487,
#                               ParameterVectorElement(t[132]): 2.1552835951879916e-06,
#                               ParameterVectorElement(t[134]): -0.010869389152065175,
#                               ParameterVectorElement(t[135]): 1.9180158488277816e-06,
#                               ParameterVectorElement(t[136]): 1.8207217175709456e-06,
#                               ParameterVectorElement(t[137]): 0.012482685940710564,
#                               ParameterVectorElement(t[138]): 3.6013761880555976e-07,
#                               ParameterVectorElement(t[139]): -2.7427581751993295e-06,
#                               ParameterVectorElement(t[2]): -0.0002262782013729623},
#     'optimal_point': array([ 7.34984769e-05,  3.23081886e-06, -2.26278201e-04,  6.37965951e-06,
#         1.44350508e-05,  3.25426447e-03,  1.28275347e-02,  7.77064000e-08,
#         7.92517093e-06,  1.54990522e-05,  8.43295862e-05,  2.67833901e-06,
#        -2.64401870e-04,  1.00075008e-05,  1.48935378e-05,  3.20965010e-03,
#         1.28056337e-02,  9.39721588e-06,  1.18060965e-05,  8.15682803e-06,
#         3.98172320e-07,  5.08798620e-04,  1.54091137e-06,  1.88558666e-06,
#        -6.70522352e-04,  3.16442389e-05, -2.76624014e-04,  2.25447338e-06,
#        -1.77530283e-06,  2.54834083e-04, -1.18412228e-04,  1.43170185e-06,
#         7.18491440e-07,  1.27378849e-06, -2.36282162e-05, -4.32882868e-04,
#        -4.33608626e-07, -7.24902798e-04, -2.58727061e-04,  7.11531125e-07,
#         1.95493706e-07,  5.52051446e-04,  2.74166090e-07,  2.58941928e-07,
#        -1.08018279e-02,  8.88340652e-06,  1.27294950e-05, -2.70851477e-04,
#         1.19877872e-06, -3.21845517e-02, -2.59476916e-06,  1.02303460e-05,
#        -3.12671571e-02, -3.31103246e-02,  4.69669187e-06, -3.38845288e-07,
#         9.51236202e-07,  6.26060637e-07, -7.47751699e-04, -2.50129552e-06,
#        -1.66596919e-02, -2.03576663e-02,  3.27263534e-09,  7.07025373e-06,
#         3.66862709e-03,  3.67308260e-06,  5.58843850e-06,  1.25396183e-02,
#         5.23669186e-06, -5.24984923e-07, -2.53754470e-04,  6.56825889e-06,
#        -2.04927515e-02, -4.34185508e-02,  3.98785963e-06,  5.56327618e-06,
#        -3.45952517e-02,  1.07530118e-05,  7.54610599e-06,  2.60797451e-04,
#        -6.56026514e-08, -3.13095703e-02,  5.99294454e-06,  7.83600992e-06,
#        -7.79555717e-02, -4.69963208e-02,  6.47797357e-06,  1.06885032e-05,
#         1.64163194e-06,  1.82964146e-05, -1.00679321e-04, -6.13282794e-07,
#        -3.32054147e-02,  2.80216009e-06,  1.28714136e-05, -4.70293063e-02,
#        -4.64484163e-02,  4.51505876e-06,  8.17965645e-06,  7.87419381e-06,
#        -2.21372914e-06,  5.21828238e-04,  6.38284830e-06,  3.69915379e-03,
#        -3.46721843e-02,  7.67694264e-06, -8.13439058e-07, -4.18241800e-02,
#         4.92986970e-06,  9.84335539e-06,  1.84662992e-07,  7.61584544e-08,
#         3.77890784e-06,  5.14505426e-06,  3.75249494e-06,  3.63432234e-06,
#         1.88447273e-06,  9.98832548e-07, -2.63252704e-02,  6.67514638e-06,
#         2.92829935e-07,  1.24674887e-06,  2.11526650e-06,  3.51288810e-06,
#         4.02143123e-06, -3.13885596e-07,  5.65305532e-07,  1.79921350e-06,
#         1.54851191e-07, -1.04811150e-02,  2.04236944e-07,  4.68474040e-04,
#         2.15528360e-06,  6.56511643e-07, -1.08693892e-02,  1.91801585e-06,
#         1.82072172e-06,  1.24826859e-02,  3.60137619e-07, -2.74275818e-06]),
#     'optimal_value': -84.20624898647324,
#     'optimizer_evals': None,
#     'optimizer_result': <qiskit.algorithms.optimizers.optimizer.OptimizerResult object at 0x7fa75ca12350>,
#     'optimizer_time': 41812.85052704811}
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 174, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 134, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 100, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 8, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 7, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z',  ...
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Y', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Y', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'X', 'Z', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'X', 'Z', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'X', 'X', 'X', 'Z', 'Y', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'X', 'Z', 'Y', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'X', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Y', 'X'): 1, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 0, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 0, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', ' ...
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -83.73683433759504
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -84.19693035318065
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -84.17683824543803
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -83.77609804923063
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -83.837910779342
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -83.93899457535333
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -84.34167928493856
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -84.66426500017258
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -83.38247412931818
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -83.92961734600976
# 50 | Counter({('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Y', 'X', 'X', 'Y', 'X', 'X'): 1, ('Y', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Y', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'X', 'Z', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'X', 'Z', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'X', 'X', 'X', 'Z', 'Y', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'X', 'Z', 'Y', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('X', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Y', 'X', 'X', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Y', 'X'): 1, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 0, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 0, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 0, ('Z', 'Y',  ...
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 174, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 134, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 100, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 8, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 7, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z',  ...
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 5, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', ' ...
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -84.36694377540167
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -83.62621329838177
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -84.1360609030994
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -83.99172321281672
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -84.51417251943512
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -84.11269513593341
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -84.09488046050423
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -83.81930516952838
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -84.18503829183038
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -84.00788190363964
# 250 | Counter({('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 5, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', ...
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 174, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 134, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 100, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 8, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 7, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z',  ...
# ...
# Original derandomized Hamiltonian Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 174, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 134, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 100, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 57, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 12, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 8, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 7, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 3, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 3, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 2, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 2, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 2, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Y', 'Y', 'X', 'X', 'X', 'X', 'X'): 2, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 2, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 1, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z',  ...
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 180, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 140, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 106, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 63, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 39, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 19, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 19, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 18, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 14, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 12, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 12, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 11, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 11, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 10, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 10, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 9, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 9, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 9, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 9, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 9, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 8, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 8, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 8, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 8, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 8, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 8, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 8, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 8, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 8, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 8, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 8, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Z', 'Y', 'Y', 'X', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'Z', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', ' ...
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -84.1179863307577
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -84.0856983814962
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -83.85431411652972
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -84.15085767402367
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -83.97924669516891
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -84.04986350684261
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -84.11844743264251
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -84.22031929678066
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -84.32942919530002
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -84.17722901365994
# 1750 | Counter({('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 180, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 140, ('X', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 106, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 63, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'X', 'X', 'X'): 39, ('Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 19, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 19, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 18, ('Z', 'Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 14, ('Z', 'X', 'X', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 12, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 12, ('Z', 'Z', 'Z', 'Y', 'X', 'Y', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 12, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 11, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 11, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 10, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'X', 'Y', 'Y', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 10, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Y', 'Z', 'X'): 10, ('Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 9, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 9, ('Z', 'X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'Z', 'Y'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'X'): 9, ('Z', 'Y', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z', 'Y', 'X', 'X', 'Y', 'X', 'X'): 9, ('Z', 'Z', 'X', 'Y', 'X', 'Z', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'X'): 9, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'X'): 9, ('Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Y', 'X', 'Y'): 9, ('Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 8, ('Z', 'X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X', 'Y', 'Y', 'Y', 'X', 'Z'): 8, ('Z', 'Y', 'Y', 'Y', 'Z', 'X', 'X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 8, ('X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 8, ('Z', 'Z', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'X', 'Z', 'Y', 'Z', 'Y'): 8, ('Z', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 8, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X', 'Y', 'Y', 'X'): 8, ('Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'X', 'X'): 8, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Y', 'Z', 'X'): 8, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Y', 'Y', 'Y', 'X', 'X'): 8, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'Y', 'X', 'X'): 8, ('Y', 'Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Z', 'Y', 'Y', 'X', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'X', 'Z', 'X', 'Z', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 8, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Y' ...
# Execution time =  18:08:22

# %%
import matplotlib.pyplot as plt 
points = measurement_range 
num_points = len(points)

plt.plot([i for i in points], [rmse_errors[i] for i in range(num_points)], 'r', label='derandomized classical shadow')
plt.xlabel('Number of measurements')
plt.ylabel('Average RMSE error')
plt.legend(loc=1)
